# %% [markdown]
# #Paquetes necesarios

# %%
import cv2  
import math 

from ultralytics import YOLO
# Out:
# WARNING ⚠️ Python>=3.10 is required, but Python==3.9.20 is currently installed

# %% [markdown]
# Modelos preentrenados, visualizando con las utilidades de ultralytics

# %%
# Carga del modelo
model = YOLO('yolo11n.pt') #Contenedores
#model = YOLO('yolo11n-seg.pt') #Máscaras
#model = YOLO('yolo11n-pose.pt')  #Pose

#Para un vídeo 
filename = "TGC23_PdH_C0056cut.mp4"
results = model(filename, show=True)

cv2.destroyAllWindows()
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.6ms
# video 1/1 (frame 2/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.7ms
# video 1/1 (frame 3/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.6ms
# video 1/1 (frame 4/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.5ms
# video 1/1 (frame 5/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.5ms
# video 1/1 (frame 6/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.5ms
# video 1/1 (frame 7/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.5ms
# video 1/1 (frame 8/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.3ms
# video 1/1 (frame 9/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.2ms
# video 1/1 (frame 10/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.1ms
# video 1/1 (frame 11/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.2ms
# video 1/1 (frame 12/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.2ms
# video 1/1 (frame 13/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.2ms
# video 1/1 (frame 14/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.2ms
# video 1/1 (frame 15/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.1ms
# video 1/1 (frame 16/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.2ms
# video 1/1 (frame 17/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.1ms
# video 1/1 (frame 18/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.1ms
# video 1/1 (frame 19/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.2ms
# video 1/1 (frame 20/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.1ms
# video 1/1 (frame 21/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.1ms
# video 1/1 (frame 22/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.2ms
# video 1/1 (frame 23/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.2ms
# video 1/1 (frame 24/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.3ms
# video 1/1 (frame 25/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.2ms
# video 1/1 (frame 26/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.2ms
# video 1/1 (frame 27/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.3ms
# video 1/1 (frame 28/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.1ms
# video 1/1 (frame 29/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.1ms
# video 1/1 (frame 30/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.2ms
# video 1/1 (frame 31/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.1ms
# video 1/1 (frame 32/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.1ms
# video 1/1 (frame 33/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.1ms
# video 1/1 (frame 34/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.1ms
# video 1/1 (frame 35/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.2ms
# video 1/1 (frame 36/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.2ms
# video 1/1 (frame 37/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.1ms
# video 1/1 (frame 38/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 13.3ms
# video 1/1 (frame 39/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 13.1ms
# video 1/1 (frame 40/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.2ms
# video 1/1 (frame 41/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.1ms
# video 1/1 (frame 42/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.1ms
# video 1/1 (frame 43/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.3ms
# video 1/1 (frame 44/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.3ms
# video 1/1 (frame 45/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.2ms
# video 1/1 (frame 46/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.2ms
# video 1/1 (frame 47/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.0ms
# video 1/1 (frame 48/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.0ms
# video 1/1 (frame 49/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.0ms
# video 1/1 (frame 50/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.1ms
# video 1/1 (frame 51/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.1ms
# video 1/1 (frame 52/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.0ms
# video 1/1 (frame 53/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.0ms
# video 1/1 (frame 54/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.1ms
# video 1/1 (frame 55/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.1ms
# video 1/1 (frame 56/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.1ms
# video 1/1 (frame 57/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.1ms
# video 1/1 (frame 58/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.0ms
# video 1/1 (frame 59/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.1ms
# video 1/1 (frame 60/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.1ms
# video 1/1 (frame 61/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.1ms
# video 1/1 (frame 62/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.0ms
# video 1/1 (frame 63/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.0ms
# video 1/1 (frame 64/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.1ms
# video 1/1 (frame 65/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.0ms
# video 1/1 (frame 66/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.1ms
# video 1/1 (frame 67/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.1ms
# video 1/1 (frame 68/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.0ms
# video 1/1 (frame 69/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.0ms
# video 1/1 (frame 70/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.1ms
# video 1/1 (frame 71/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.1ms
# video 1/1 (frame 72/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.0ms
# video 1/1 (frame 73/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 12.9ms
# video 1/1 (frame 74/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.0ms
# video 1/1 (frame 75/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.2ms
# video 1/1 (frame 76/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.0ms
# video 1/1 (frame 77/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.0ms
# video 1/1 (frame 78/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.0ms
# video 1/1 (frame 79/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.1ms
# video 1/1 (frame 80/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.0ms
# video 1/1 (frame 81/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.0ms
# video 1/1 (frame 82/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.1ms
# video 1/1 (frame 83/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.1ms
# video 1/1 (frame 84/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.0ms
# video 1/1 (frame 85/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.0ms
# video 1/1 (frame 86/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.0ms
# video 1/1 (frame 87/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.0ms
# video 1/1 (frame 88/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 1 horse, 13.1ms
# video 1/1 (frame 89/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 1 horse, 12.9ms
# video 1/1 (frame 90/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 1 horse, 13.0ms
# video 1/1 (frame 91/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 1 horse, 13.1ms
# video 1/1 (frame 92/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 1 horse, 13.1ms
# video 1/1 (frame 93/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 1 horse, 13.0ms
# video 1/1 (frame 94/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 1 horse, 13.0ms
# video 1/1 (frame 95/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 1 horse, 13.1ms
# video 1/1 (frame 96/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.2ms
# video 1/1 (frame 97/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 1 horse, 13.0ms
# video 1/1 (frame 98/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.0ms
# video 1/1 (frame 99/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 13.1ms
# video 1/1 (frame 100/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 13.0ms
# video 1/1 (frame 101/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 13.0ms
# video 1/1 (frame 102/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 1 horse, 13.0ms
# video 1/1 (frame 103/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 13.1ms
# video 1/1 (frame 104/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 1 horse, 13.1ms
# video 1/1 (frame 105/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.1ms
# video 1/1 (frame 106/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.0ms
# video 1/1 (frame 107/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.0ms
# video 1/1 (frame 108/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.0ms
# video 1/1 (frame 109/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.0ms
# video 1/1 (frame 110/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 13.1ms
# video 1/1 (frame 111/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.0ms
# video 1/1 (frame 112/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.0ms
# video 1/1 (frame 113/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 12.9ms
# video 1/1 (frame 114/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.0ms
# video 1/1 (frame 115/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.1ms
# video 1/1 (frame 116/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.0ms
# video 1/1 (frame 117/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.0ms
# video 1/1 (frame 118/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.0ms
# video 1/1 (frame 119/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.2ms
# video 1/1 (frame 120/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.1ms
# video 1/1 (frame 121/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.1ms
# video 1/1 (frame 122/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.0ms
# video 1/1 (frame 123/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.0ms
# video 1/1 (frame 124/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.1ms
# video 1/1 (frame 125/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.1ms
# video 1/1 (frame 126/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.1ms
# video 1/1 (frame 127/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.1ms
# video 1/1 (frame 128/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.0ms
# video 1/1 (frame 129/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.0ms
# video 1/1 (frame 130/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.1ms
# video 1/1 (frame 131/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.1ms
# video 1/1 (frame 132/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.0ms
# video 1/1 (frame 133/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.0ms
# video 1/1 (frame 134/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.2ms
# video 1/1 (frame 135/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.1ms
# video 1/1 (frame 136/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.0ms
# video 1/1 (frame 137/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.0ms
# video 1/1 (frame 138/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.0ms
# video 1/1 (frame 139/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.2ms
# video 1/1 (frame 140/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.1ms
# video 1/1 (frame 141/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.0ms
# video 1/1 (frame 142/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.0ms
# video 1/1 (frame 143/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.1ms
# video 1/1 (frame 144/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.1ms
# video 1/1 (frame 145/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.0ms
# video 1/1 (frame 146/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.0ms
# video 1/1 (frame 147/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.1ms
# video 1/1 (frame 148/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.1ms
# video 1/1 (frame 149/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 5 persons, 13.0ms
# video 1/1 (frame 150/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 5 persons, 13.1ms
# video 1/1 (frame 151/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 5 persons, 13.1ms
# video 1/1 (frame 152/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 5 persons, 13.1ms
# video 1/1 (frame 153/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 5 persons, 13.0ms
# video 1/1 (frame 154/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.0ms
# video 1/1 (frame 155/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.0ms
# video 1/1 (frame 156/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.1ms
# video 1/1 (frame 157/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.0ms
# video 1/1 (frame 158/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.1ms
# video 1/1 (frame 159/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.1ms
# video 1/1 (frame 160/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.0ms
# video 1/1 (frame 161/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.1ms
# video 1/1 (frame 162/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.1ms
# video 1/1 (frame 163/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.1ms
# video 1/1 (frame 164/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.1ms
# video 1/1 (frame 165/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 12.9ms
# video 1/1 (frame 166/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.1ms
# video 1/1 (frame 167/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.1ms
# video 1/1 (frame 168/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.1ms
# video 1/1 (frame 169/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.0ms
# video 1/1 (frame 170/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.1ms
# video 1/1 (frame 171/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.1ms
# video 1/1 (frame 172/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.1ms
# video 1/1 (frame 173/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.0ms
# video 1/1 (frame 174/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.0ms
# video 1/1 (frame 175/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.1ms
# video 1/1 (frame 176/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.1ms
# video 1/1 (frame 177/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.0ms
# video 1/1 (frame 178/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 5 persons, 13.1ms
# video 1/1 (frame 179/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 5 persons, 13.0ms
# video 1/1 (frame 180/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.1ms
# video 1/1 (frame 181/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.1ms
# video 1/1 (frame 182/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.1ms
# video 1/1 (frame 183/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.0ms
# video 1/1 (frame 184/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.0ms
# video 1/1 (frame 185/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.0ms
# video 1/1 (frame 186/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.1ms
# video 1/1 (frame 187/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.1ms
# video 1/1 (frame 188/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.0ms
# video 1/1 (frame 189/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.0ms
# video 1/1 (frame 190/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.1ms
# video 1/1 (frame 191/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.2ms
# video 1/1 (frame 192/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 5 persons, 13.0ms
# video 1/1 (frame 193/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.1ms
# video 1/1 (frame 194/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.0ms
# video 1/1 (frame 195/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 5 persons, 1 horse, 13.2ms
# video 1/1 (frame 196/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 1 horse, 13.0ms
# video 1/1 (frame 197/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 1 horse, 13.0ms
# video 1/1 (frame 198/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 4 persons, 13.0ms
# video 1/1 (frame 199/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13.1ms
# video 1/1 (frame 200/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 13
375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 1 bicycle, 1 backpack, 13.0ms
# video 1/1 (frame 310/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 1 bicycle, 1 backpack, 13.0ms
# video 1/1 (frame 311/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 1 bicycle, 1 backpack, 13.1ms
# video 1/1 (frame 312/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 1 bicycle, 1 motorcycle, 1 backpack, 13.1ms
# video 1/1 (frame 313/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 1 bicycle, 1 backpack, 13.0ms
# video 1/1 (frame 314/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 1 bicycle, 13.1ms
# video 1/1 (frame 315/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 3 persons, 1 bicycle, 13.0ms
# video 1/1 (frame 316/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 1 bicycle, 13.0ms
# video 1/1 (frame 317/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 13.0ms
# video 1/1 (frame 318/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 1 person, 1 bicycle, 13.0ms
# video 1/1 (frame 319/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 1 person, 13.0ms
# video 1/1 (frame 320/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 1 person, 13.0ms
# video 1/1 (frame 321/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 1 person, 13.0ms
# video 1/1 (frame 322/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 1 person, 13.1ms
# video 1/1 (frame 323/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 1 person, 13.1ms
# video 1/1 (frame 324/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 1 person, 13.1ms
# video 1/1 (frame 325/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 1 person, 13.0ms
# video 1/1 (frame 326/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 1 person, 13.0ms
# video 1/1 (frame 327/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 1 person, 13.2ms
# video 1/1 (frame 328/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 1 person, 13.1ms
# video 1/1 (frame 329/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 1 person, 13.0ms
# video 1/1 (frame 330/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 1 person, 13.2ms
# video 1/1 (frame 331/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 1 person, 13.1ms
# video 1/1 (frame 332/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 1 person, 13.0ms
# video 1/1 (frame 333/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 1 person, 13.0ms
# video 1/1 (frame 334/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 1 person, 13.1ms
# video 1/1 (frame 335/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 1 person, 13.2ms
# video 1/1 (frame 336/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 1 person, 13.0ms
# video 1/1 (frame 337/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 1 person, 12.9ms
# video 1/1 (frame 338/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 1 person, 13.1ms
# video 1/1 (frame 339/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 1 person, 13.1ms
# video 1/1 (frame 340/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 1 person, 13.0ms
# video 1/1 (frame 341/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 1 person, 13.0ms
# video 1/1 (frame 342/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 1 person, 13.0ms
# video 1/1 (frame 343/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 1 person, 13.1ms
# video 1/1 (frame 344/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 1 person, 13.1ms
# video 1/1 (frame 345/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 1 person, 13.0ms
# video 1/1 (frame 346/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 1 person, 13.1ms
# video 1/1 (frame 347/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 1 person, 13.0ms
# video 1/1 (frame 348/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 1 person, 13.1ms
# video 1/1 (frame 349/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 1 person, 13.0ms
# video 1/1 (frame 350/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 1 person, 13.0ms
# video 1/1 (frame 351/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 1 person, 13.0ms
# video 1/1 (frame 352/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 13.0ms
# video 1/1 (frame 353/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 13.0ms
# video 1/1 (frame 354/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 13.0ms
# video 1/1 (frame 355/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 13.1ms
# video 1/1 (frame 356/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 13.0ms
# video 1/1 (frame 357/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 13.0ms
# video 1/1 (frame 358/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 13.0ms
# video 1/1 (frame 359/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 13.0ms
# video 1/1 (frame 360/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 13.0ms
# video 1/1 (frame 361/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 12.9ms
# video 1/1 (frame 362/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 13.0ms
# video 1/1 (frame 363/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 13.0ms
# video 1/1 (frame 364/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 1 person, 13.1ms
# video 1/1 (frame 365/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 1 person, 13.0ms
# video 1/1 (frame 366/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 1 person, 13.0ms
# video 1/1 (frame 367/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 1 person, 13.0ms
# video 1/1 (frame 368/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 1 person, 13.1ms
# video 1/1 (frame 369/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 1 person, 13.0ms
# video 1/1 (frame 370/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 1 person, 13.1ms
# video 1/1 (frame 371/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 1 person, 13.1ms
# video 1/1 (frame 372/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 1 person, 13.0ms
# video 1/1 (frame 373/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 12.9ms
# video 1/1 (frame 374/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 13.0ms
# video 1/1 (frame 375/375) /home/oscar/Info/VC/Entrega/PracticasVC/VC_P4/TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 13.2ms
# Speed: 2.1ms preprocess, 13.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)

# %% [markdown]
# Desde cámara, detección con yolo11, modelo nano. Visualización propia con OpenCV

# %%
# Carga del modelo, descarga en disco si no está presente en la carpeta
model = YOLO('yolo11n.pt') #Contenedores

# Etiqueta de las distintas clases
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ]


# Captura desde la webcam
vid = cv2.VideoCapture(0)
  
while(True):      
    # fotograma a fotograma
    ret, img = vid.read()
  
    # si hay imagen válida
    if ret:  
        # Detecta en la imagen
        results = model(img, stream=True)
        
        # Para cada detección
        for r in results:
            boxes = r.boxes

            for box in boxes:
                # Contenedor
                x1, y1, x2, y2 = box.xyxy[0]
                x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values
                
                # Confianza
                confidence = math.ceil((box.conf[0]*100))/100
                print("Confianza --->",confidence)

                # Clase
                cls = int(box.cls[0])
                print("Clase -->", classNames[cls])

                # Convierte identificador numérico de clase a un color RGB
                escala = int((cls / len(classNames)) * 255 * 3)
                if escala >= 255*2:
                    R = 255
                    G = 255
                    B = escala - 255*2
                else:
                    if escala >= 255:
                        R = 255
                        G = escala - 255
                        B = 0
                    else:
                        R = escala
                        G = 0
                        B = 0

                # Dibuja el contenedor y clase
                cv2.rectangle(img, (x1, y1), (x2, y2), (R, G, B), 3)
                cv2.putText(img, classNames[cls] , [x1, y1], cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, B), 2)

        # Muestra fotograma
        cv2.imshow('Vid', img)
    
    # Detenemos pulsado ESC
    if cv2.waitKey(20) == 27:
        break
  
# Libera el objeto de captura
vid.release()
# Destruye ventanas
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 64.1ms
# Speed: 2.7ms preprocess, 64.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.7ms
# Confianza ---> 0.26
# Clase --> person
# Speed: 2.6ms preprocess, 17.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 17.8ms
# Speed: 2.5ms preprocess, 17.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.8ms
# Confianza ---> 0.37
# Clase --> person
# Speed: 2.4ms preprocess, 17.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.9ms
# Confianza ---> 0.53
# Clase --> person
# Speed: 2.5ms preprocess, 17.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.8ms
# Confianza ---> 0.8
# Clase --> person
# Speed: 2.7ms preprocess, 17.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.8ms
# Confianza ---> 0.81
# Clase --> person
# Speed: 2.7ms preprocess, 17.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.8ms
# Confianza ---> 0.78
# Clase --> person
# Speed: 2.3ms preprocess, 17.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 18.2ms
# Confianza ---> 0.77
# Clase --> person
# Speed: 2.3ms preprocess, 18.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.7ms
# Confianza ---> 0.83
# Clase --> person
# Speed: 2.4ms preprocess, 17.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.8ms
# Confianza ---> 0.84
# Clase --> person
# Speed: 4.0ms preprocess, 17.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.7ms
# Confianza ---> 0.85
# Clase --> person
# Speed: 2.0ms preprocess, 17.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.8ms
# Confianza ---> 0.8
# Clase --> person
# Speed: 2.2ms preprocess, 17.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.7ms
# Confianza ---> 0.8
# Clase --> person
# Speed: 1.9ms preprocess, 17.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.6ms
# Confianza ---> 0.85
# Clase --> person
# Speed: 2.0ms preprocess, 17.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.6ms
# Confianza ---> 0.82
# Clase --> person
# Speed: 2.1ms preprocess, 17.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.7ms
# Confianza ---> 0.78
# Clase --> person
# Speed: 2.2ms preprocess, 17.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.6ms
# Confianza ---> 0.76
# Clase --> person
# Speed: 2.0ms preprocess, 17.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.7ms
# Confianza ---> 0.71
# Clase --> person
# Speed: 2.0ms preprocess, 17.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.6ms
# Confianza ---> 0.67
# Clase --> person
# Speed: 2.1ms preprocess, 17.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.7ms
# Confianza ---> 0.68
# Clase --> person
# Speed: 2.2ms preprocess, 17.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.6ms
# Confianza ---> 0.63
# Clase --> person
# Speed: 2.2ms preprocess, 17.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.7ms
# Confianza ---> 0.74
# Clase --> person
# Speed: 2.5ms preprocess, 17.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.6ms
# Confianza ---> 0.75
# Clase --> person
# Speed: 2.0ms preprocess, 17.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.7ms
# Confianza ---> 0.77
# Clase --> person
# Speed: 4.1ms preprocess, 17.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.6ms
# Confianza ---> 0.76
# Clase --> person
# Speed: 2.3ms preprocess, 17.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.6ms
# Confianza ---> 0.83
# Clase --> person
# Speed: 2.1ms preprocess, 17.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.6ms
# Confianza ---> 0.85
# Clase --> person
# Speed: 2.0ms preprocess, 17.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.5ms
# Confianza ---> 0.86
# Clase --> person
# Speed: 2.0ms preprocess, 17.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.6ms
# Confianza ---> 0.82
# Clase --> person
# Speed: 2.1ms preprocess, 17.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.6ms
# Confianza ---> 0.83
# Clase --> person
# Speed: 1.9ms preprocess, 17.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.6ms
# Confianza ---> 0.82
# Clase --> person
# Speed: 2.2ms preprocess, 17.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.4ms
# Confianza ---> 0.83
# Clase --> person
# Speed: 2.0ms preprocess, 17.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.5ms
# Confianza ---> 0.87
# Clase --> person
# Speed: 2.3ms preprocess, 17.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.5ms
# Confianza ---> 0.86
# Clase --> person
# Speed: 2.1ms preprocess, 17.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.5ms
# Confianza ---> 0.87
# Clase --> person
# Speed: 2.1ms preprocess, 17.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.5ms
# Confianza ---> 0.84
# Clase --> person
# Speed: 2.6ms preprocess, 17.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.5ms
# Confianza ---> 0.84
# Clase --> person
# Speed: 1.8ms preprocess, 17.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.5ms
# Confianza ---> 0.82
# Clase --> person
# Speed: 2.0ms preprocess, 17.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.5ms
# Confianza ---> 0.85
# Clase --> person
# Speed: 1.9ms preprocess, 17.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.4ms
# Confianza ---> 0.86
# Clase --> person
# Speed: 2.1ms preprocess, 17.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.5ms
# Confianza ---> 0.78
# Clase --> person
# Speed: 2.8ms preprocess, 17.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.5ms
# Confianza ---> 0.79
# Clase --> person
# Speed: 1.9ms preprocess, 17.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.5ms
# Confianza ---> 0.77
# Clase --> person
# Speed: 2.1ms preprocess, 17.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.5ms
# Confianza ---> 0.82
# Clase --> person
# Speed: 3.3ms preprocess, 17.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.4ms
# Confianza ---> 0.83
# Clase --> person
# Speed: 2.2ms preprocess, 17.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.3ms
# Confianza ---> 0.81
# Clase --> person
# Speed: 2.2ms preprocess, 17.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.4ms
# Confianza ---> 0.81
# Clase --> person
# Speed: 2.5ms preprocess, 17.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.4ms
# Confianza ---> 0.8
# Clase --> person
# Speed: 2.1ms preprocess, 17.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.5ms
# Confianza ---> 0.76
# Clase --> person
# Speed: 2.0ms preprocess, 17.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.4ms
# Confianza ---> 0.8
# Clase --> person
# Speed: 2.9ms preprocess, 17.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.4ms
# Confianza ---> 0.8
# Clase --> person
# Speed: 2.0ms preprocess, 17.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.4ms
# Confianza ---> 0.8
# Clase --> person
# Speed: 1.9ms preprocess, 17.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.4ms
# Confianza ---> 0.77
# Clase --> person
# Speed: 1.7ms preprocess, 17.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.4ms
# Confianza ---> 0.47
# Clase --> person
# Speed: 2.1ms preprocess, 17.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.4ms
# Confianza ---> 0.49
# Clase --> person
# Speed: 2.1ms preprocess, 17.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.4ms
# Confianza ---> 0.71
# Clase --> person
# Speed: 2.0ms preprocess, 17.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.4ms
# Confianza ---> 0.54
# Clase --> person
# Speed: 2.1ms preprocess, 17.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.4ms
# Confianza ---> 0.6
# Clase --> person
# Speed: 2.1ms preprocess, 17.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.5ms
# Confianza ---> 0.74
# Clase --> person
# Speed: 2.1ms preprocess, 17.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 17.4ms
# Confianza ---> 0.6
# Clase --> person
# Confianza ---> 0.4
# Clase --> person
# Speed: 2.1ms preprocess, 17.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.4ms
# Confianza ---> 0.72
# Clase --> person
# Speed: 2.0ms preprocess, 17.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.4ms
# Confianza ---> 0.74
# Clase --> person
# Speed: 2.1ms preprocess, 17.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.3ms
# Confianza ---> 0.79
# Clase --> person
# Speed: 2.0ms preprocess, 17.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.3ms
# Confianza ---> 0.84
# Clase --> person
# Speed: 2.0ms preprocess, 17.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.3ms
# Confianza ---> 0.85
# Clase --> person
# Speed: 2.5ms preprocess, 17.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.4ms
# Confianza ---> 0.86
# Clase --> person
# Speed: 2.0ms preprocess, 17.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.3ms
# Confianza ---> 0.84
# Clase --> person
# Speed: 1.9ms preprocess, 17.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 17.4ms
# Confianza ---> 0.85
# Clase --> person
# Confianza ---> 0.27
# Clase --> cell phone
# Speed: 2.0ms preprocess, 17.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 17.4ms
# Confianza ---> 0.87
# Clase --> person
# Confianza ---> 0.35
# Clase --> bottle
# Speed: 2.0ms preprocess, 17.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 17.3ms
# Confianza ---> 0.85
# Clase --> person
# Confianza ---> 0.45
# Clase --> bottle
# Speed: 2.0ms preprocess, 17.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.4ms
# Confianza ---> 0.79
# Clase --> person
# Speed: 2.0ms preprocess, 17.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.4ms
# Confianza ---> 0.84
# Clase --> person
# Speed: 2.2ms preprocess, 17.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.3ms
# Confianza ---> 0.84
# Clase --> person
# Speed: 1.9ms preprocess, 17.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 bottles, 17.4ms
# Confianza ---> 0.84
# Clase --> person
# Confianza ---> 0.29
# Clase --> bottle
# Confianza ---> 0.26
# Clase --> bottle
# Speed: 1.8ms preprocess, 17.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.3ms
# Confianza ---> 0.83
# Clase --> person
# Speed: 2.0ms preprocess, 17.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.4ms
# Confianza ---> 0.88
# Clase --> person
# Speed: 2.1ms preprocess, 17.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.3ms
# Confianza ---> 0.83
# Clase --> person
# Speed: 1.8ms preprocess, 17.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.4ms
# Confianza ---> 0.84
# Clase --> person
# Speed: 2.0ms preprocess, 17.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.1ms
# Confianza ---> 0.78
# Clase --> person
# Speed: 1.9ms preprocess, 20.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.3ms
# Confianza ---> 0.77
# Clase --> person
# Speed: 1.6ms preprocess, 17.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.6ms
# Confianza ---> 0.83
# Clase --> person
# Speed: 2.0ms preprocess, 17.6ms inference, 10.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 20.0ms
# Confianza ---> 0.82
# Clase --> person
# Confianza ---> 0.43
# Clase --> bottle
# Speed: 3.8ms preprocess, 20.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 17.3ms
# Confianza ---> 0.83
# Clase --> person
# Confianza ---> 0.39
# Clase --> bottle
# Speed: 2.1ms preprocess, 17.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 17.3ms
# Confianza ---> 0.83
# Clase --> person
# Confianza ---> 0.3
# Clase --> chair
# Speed: 1.8ms preprocess, 17.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 chair, 17.4ms
# Confianza ---> 0.84
# Clase --> person
# Confianza ---> 0.39
# Clase --> bottle
# Confianza ---> 0.34
# Clase --> chair
# Speed: 3.4ms preprocess, 17.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 chair, 17.3ms
# Confianza ---> 0.84
# Clase --> person
# Confianza ---> 0.38
# Clase --> bottle
# Confianza ---> 0.34
# Clase --> chair
# Speed: 1.8ms preprocess, 17.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 chair, 17.3ms
# Confianza ---> 0.85
# Clase --> person
# Confianza ---> 0.36
# Clase --> chair
# Confianza ---> 0.34
# Clase --> bottle
# Speed: 2.1ms preprocess, 17.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 chair, 17.3ms
# Confianza ---> 0.86
# Clase --> person
# Confianza ---> 0.36
# Clase --> bottle
# Confianza ---> 0.26
# Clase --> chair
# Speed: 3.0ms preprocess, 17.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 chair, 17.4ms
# Confianza ---> 0.85
# Clase --> person
# Confianza ---> 0.41
# Clase --> bottle
# Confianza ---> 0.3
# Clase --> chair
# Speed: 2.2ms preprocess, 17.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 17.3ms
# Confianza ---> 0.87
# Clase --> person
# Confianza ---> 0.38
# Clase --> bottle
# Speed: 2.0ms preprocess, 17.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 20.0ms
# Confianza ---> 0.86
# Clase --> person
# Confianza ---> 0.29
# Clase --> bottle
# Speed: 2.7ms preprocess, 20.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 20.9ms
# Confianza ---> 0.86
# Clase --> person
# Confianza ---> 0.31
# Clase --> bottle
# Speed: 2.3ms preprocess, 20.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 17.4ms
# Confianza ---> 0.85
# Clase --> person
# Confianza ---> 0.27
# Clase --> bottle
# Speed: 2.2ms preprocess, 17.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.3ms
# Confianza ---> 0.85
# Clase --> person
# Speed: 2.9ms preprocess, 17.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 19.6ms
# Confianza ---> 0.86
# Clase --> person
# Speed: 2.0ms preprocess, 19.6ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.4ms
# Confianza ---> 0.85
# Clase --> person
# Speed: 2.2ms preprocess, 17.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.3ms
# Confianza ---> 0.85
# Clase --> person
# Speed: 3.3ms preprocess, 17.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.3ms
# Confianza ---> 0.86
# Clase --> person
# Speed: 2.0ms preprocess, 17.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Confianza ---> 0.85
# Clase --> person
# Speed: 1.8ms preprocess, 20.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.4ms
# Confianza ---> 0.84
# Clase --> person
# Speed: 3.1ms preprocess, 17.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.6ms
# Confianza ---> 0.83
# Clase --> person
# Speed: 2.5ms preprocess, 17.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 17.7ms
# Confianza ---> 0.83
# Clase --> person
# Confianza ---> 0.31
# Clase --> bottle
# Speed: 1.9ms preprocess, 17.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 17.6ms
# Confianza ---> 0.87
# Clase --> person
# Confianza ---> 0.32
# Clase --> bottle
# Speed: 2.6ms preprocess, 17.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.6ms
# Confianza ---> 0.82
# Clase --> person
# Speed: 2.2ms preprocess, 17.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.7ms
# Confianza ---> 0.87
# Clase --> person
# Speed: 2.1ms preprocess, 17.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 17.8ms
# Confianza ---> 0.88
# Clase --> person
# Confianza ---> 0.49
# Clase --> bottle
# Speed: 2.1ms preprocess, 17.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 17.7ms
# Confianza ---> 0.88
# Clase --> person
# Confianza ---> 0.4
# Clase --> bottle
# Speed: 2.1ms preprocess, 17.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 17.6ms
# Confianza ---> 0.89
# Clase --> person
# Confianza ---> 0.39
# Clase --> chair
# Speed: 1.8ms preprocess, 17.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 17.6ms
# Confianza ---> 0.89
# Clase --> person
# Confianza ---> 0.27
# Clase --> chair
# Speed: 2.2ms preprocess, 17.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 chair, 17.7ms
# Confianza ---> 0.91
# Clase --> person
# Confianza ---> 0.45
# Clase --> chair
# Confianza ---> 0.41
# Clase --> bottle
# Speed: 2.2ms preprocess, 17.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 chair, 17.6ms
# Confianza ---> 0.89
# Clase --> person
# Confianza ---> 0.42
# Clase --> chair
# Confianza ---> 0.34
# Clase --> bottle
# Speed: 2.1ms preprocess, 17.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 17.6ms
# Confianza ---> 0.91
# Clase --> person
# Confianza ---> 0.5
# Clase --> chair
# Speed: 2.1ms preprocess, 17.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 17.7ms
# Confianza ---> 0.9
# Clase --> person
# Confianza ---> 0.43
# Clase --> chair
# Speed: 2.2ms preprocess, 17.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 17.6ms
# Confianza ---> 0.9
# Clase --> person
# Confianza ---> 0.52
# Clase --> chair
# Speed: 1.8ms preprocess, 17.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 chair, 17.7ms
# Confianza ---> 0.9
# Clase --> person
# Confianza ---> 0.42
# Clase --> chair
# Confianza ---> 0.26
# Clase --> bottle
# Speed: 1.9ms preprocess, 17.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 chair, 17.6ms
# Confianza ---> 0.9
# Clase --> person
# Confianza ---> 0.49
# Clase --> chair
# Confianza ---> 0.3
# Clase --> bottle
# Speed: 2.2ms preprocess, 17.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 chair, 17.7ms
# Confianza ---> 0.91
# Clase --> person
# Confianza ---> 0.49
# Clase --> chair
# Confianza ---> 0.41
# Clase --> bottle
# Speed: 1.6ms preprocess, 17.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 chair, 17.6ms
# Confianza ---> 0.9
# Clase --> person
# Confianza ---> 0.52
# Clase --> chair
# Confianza ---> 0.49
# Clase --> bottle
# Speed: 2.4ms preprocess, 17.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 17.7ms
# Confianza ---> 0.91
# Clase --> person
# Confianza ---> 0.41
# Clase --> chair
# Speed: 1.9ms preprocess, 17.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 17.7ms
# Confianza ---> 0.9
# Clase --> person
# Confianza ---> 0.49
# Clase --> chair
# Speed: 3.6ms preprocess, 17.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 17.7ms
# Confianza ---> 0.86
# Clase --> person
# Confianza ---> 0.58
# Clase --> chair
# Speed: 1.9ms preprocess, 17.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 17.7ms
# Confianza ---> 0.9
# Clase --> person
# Confianza ---> 0.33
# Clase --> chair
# Speed: 2.0ms preprocess, 17.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 17.7ms
# Confianza ---> 0.89
# Clase --> person
# Confianza ---> 0.35
# Clase --> chair
# Speed: 2.6ms preprocess, 17.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 chair, 17.7ms
# Confianza ---> 0.87
# Clase --> person
# Confianza ---> 0.38
# Clase --> bottle
# Confianza ---> 0.31
# Clase --> chair
# Speed: 2.3ms preprocess, 17.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 chair, 17.7ms
# Confianza ---> 0.88
# Clase --> person
# Confianza ---> 0.37
# Clase --> bottle
# Confianza ---> 0.36
# Clase --> chair
# Speed: 2.2ms preprocess, 17.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 17.7ms
# Confianza ---> 0.85
# Clase --> person
# Confianza ---> 0.35
# Clase --> chair
# Confianza ---> 0.29
# Clase --> chair
# Speed: 2.1ms preprocess, 17.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 17.6ms
# Confianza ---> 0.9
# Clase --> person
# Confianza ---> 0.4
# Clase --> chair
# Speed: 2.0ms preprocess, 17.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.7ms
# Confianza ---> 0.86
# Clase --> person
# Speed: 2.0ms preprocess, 17.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.7ms
# Confianza ---> 0.8
# Clase --> person
# Speed: 2.6ms preprocess, 17.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 17.6ms
# Confianza ---> 0.87
# Clase --> person
# Confianza ---> 0.35
# Clase --> chair
# Speed: 2.1ms preprocess, 17.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 17.7ms
# Confianza ---> 0.88
# Clase --> person
# Confianza ---> 0.32
# Clase --> chair
# Speed: 1.9ms preprocess, 17.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 17.7ms
# Confianza ---> 0.91
# Clase --> person
# Confianza ---> 0.31
# Clase --> chair
# Speed: 3.3ms preprocess, 17.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 chair, 17.7ms
# Confianza ---> 0.89
# Clase --> person
# Confianza ---> 0.4
# Clase --> chair
# Confianza ---> 0.33
# Clase --> bottle
# Speed: 2.0ms preprocess, 17.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 17.8ms
# Confianza ---> 0.9
# Clase --> person
# Confianza ---> 0.28
# Clase --> chair
# Speed: 2.2ms preprocess, 17.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.7ms
# Confianza ---> 0.89
# Clase --> person
# Speed: 2.5ms preprocess, 17.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 17.7ms
# Confianza ---> 0.86
# Clase --> person
# Confianza ---> 0.4
# Clase --> bottle
# Speed: 1.9ms preprocess, 17.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.6ms
# Confianza ---> 0.86
# Clase --> person
# Speed: 2.1ms preprocess, 17.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 17.8ms
# Confianza ---> 0.89
# Clase --> person
# Confianza ---> 0.31
# Clase --> bottle
# Speed: 1.9ms preprocess, 17.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.7ms
# Confianza ---> 0.9
# Clase --> person
# Speed: 2.2ms preprocess, 17.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.6ms
# Confianza ---> 0.91
# Clase --> person
# Speed: 2.2ms preprocess, 17.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.8ms
# Confianza ---> 0.91
# Clase --> person
# Speed: 2.6ms preprocess, 17.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)

# %% [markdown]
# Seguimiento. Requiere instalar lap con pip install lap

# %%
from collections import defaultdict
import numpy as np

# Carga del modelo, descarga en disco si no está presente en la carpeta
model = YOLO('yolo11n.pt') #Contenedores

# Etiqueta de las distintas clases
classNames = ["person", "bicycle", "car"]


# Captura desde la webcam
vid = cv2.VideoCapture(0)
track_history = defaultdict(lambda: [])
  
while(True):      
    # fotograma a fotograma
    ret, img = vid.read()
  
    # si hay imagen válida
    if ret:  
        # Seguimiento, con persistencia entre fotogramas
        results = model.track(img, persist=True, classes = [0,1,2])

        if 0:
            if results is not None:
                print(results[0])
                boxes = results[0].boxes.xywh.cpu()
                track_ids = results[0].boxes.id.int().cpu().tolist()
                annotated_frame = results[0].plot()
                for box, track_id in zip(boxes, track_ids):
                    x, y, w, h = box
                    track = track_history[track_id]
                    track.append((float(x), float(y)))
                    if len(track) > 30:
                        track.pop(0)
                    points = np.hstack(track).astype(np.int32).reshape((-1, 1, 2))
                    cv2.polylines(annotated_frame, [points], isClosed=False, color=(230, 230, 230), thickness=10)
                cv2.imshow("YOLO11 Tracking", annotated_frame)
                if cv2.waitKey(1) & 0xFF == ord("q"):
                    break
        

        
        # Para cada detección
        for r in results:
            boxes = r.boxes

            for box in boxes:
                # Contenedor
                x1, y1, x2, y2 = box.xyxy[0]
                x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values

                #Etiqueta de seguimiento
                if box.id is not None:
                    track_id = str(int(box.id[0].tolist()))
                else:
                    track_id = ''
                
                # Confianza
                confidence = math.ceil((box.conf[0]*100))/100
                print("Confianza --->",confidence)

                # Clase
                cls = int(box.cls[0])
                print("Clase -->", classNames[cls])

                # Convierte identificador numérico de clase a un color RGB
                escala = int((cls / len(classNames)) * 255 * 3)
                if escala >= 255*2:
                    R = 255
                    G = 255
                    B = escala - 255*2
                else:
                    if escala >= 255:
                        R = 255
                        G = escala - 255
                        B = 0
                    else:
                        R = escala
                        G = 0
                        B = 0

                # Dibuja el contenedor y clase
                cv2.rectangle(img, (x1, y1), (x2, y2), (R, G, B), 3)
                cv2.putText(img, track_id + ' ' + classNames[cls] , [x1, y1], cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, B), 2)

        # Muestra fotograma
        cv2.imshow('Vid', img)
    
    # Detenemos pulsado ESC
    if cv2.waitKey(20) == 27:
        break
  
# Libera el objeto de captura
vid.release()
# Destruye ventanas
cv2.destroyAllWindows()

# %% [markdown]
# Intregración con seguimiento (tracking)
# !!!!!!!!!Nota: he tenido que bajar a la versión de python 3.9.5 e instalar lap con pip install lap

# %%
# Carga del modelo
model = YOLO('yolo11n.pt') #Contenedores
#model = YOLO('yolov11n-seg.pt') #Máscaras
#model = YOLO('yolo11n-pose.pt')  #Pose

#Para un vídeo 
filename = "TGC23_PdH_C0056cut.mp4"
results = model.track(source=filename, show=True)  # BoT-SORT tracker (por defecto)
#results = model.track(source=filename, show=True, tracker="bytetrack.yaml")  # ByteTrack tracker

cv2.destroyAllWindows()

# %% [markdown]
# Reconocimiento de caracteres tras instalar pytesseract y tesseract

# %%
# Tesseract
import cv2
import pytesseract
from pytesseract import Output

# Previamente debes descargar los ejecutables
# Si la ruta de Tesseract no está en el PATH, ruta al ejecutable
pytesseract.pytesseract.tesseract_cmd = r'C:/Program Files/Tesseract-OCR/tesseract'

# Lenguajes disponibles
print(pytesseract.get_languages(config=''))

#Cargo imagen y ocnvierto a RGB
img = cv2.imread('ocr_test.tif') 

if img is not None:
    #Convierte a RGB antes de procesar
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    #Texto localizado
    print(pytesseract.image_to_string(img))

    #Texto y localización en imagen de cada palabra
    d = pytesseract.image_to_data(img_rgb, output_type=Output.DICT)

    n_boxes = len(d['text'])
    for i in range(n_boxes):
        #Nivel de confianza
        if int(d['conf'][i]) > 60:
            text = d['text'][i]
            conf = d['conf'][i]
            (x, y, w, h) = (d['left'][i], d['top'][i], d['width'][i], d['height'][i])
            cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)

            print(f'Texto: {text} ({conf:.2f}%)\nContenedor: {x,y,x+w,y+h}')

    cv2.imshow('img', img_rgb)
    cv2.waitKey(-1)

   

else:
    print('Error de imagen')

# %% [markdown]
# Reconocimiento de caracteres tras instalar easyocr

# %%
import easyocr

#Carga del modelo de lengua
reader = easyocr.Reader(['es']) 

#Reconocimiento de una imagen
res = reader.readtext('ocr_test.tif')

for (bbox, text, prob) in res:
    # Coordenadas en orden 
    (top_left, top_right, bottom_right, bottom_left) = bbox
    print(f'\nTexto: {text}\nProbabilidad: {prob:.2f}\nContenedor: {tuple(map(int, top_left)),tuple(map(int, bottom_right))}')


#Con restricción de caracteres reconocibles
#result = reader.readtext('toy.tif', allowlist ='0123456789')
